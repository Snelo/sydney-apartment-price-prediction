# %% [markdown]
# # Importing Data from RBA
# The webpage https://www.rba.gov.au/statistics/cash-rate/ has the history of the cash rates
# * https://www.rba.gov.au/statistics/tables/csv/g1-data.csv has the Consumer Price Index dating back to 1922
# * https://www.rba.gov.au/statistics/tables/csv/f6-data.csv has the lending rates from 31 July 2019.

# %%
import pandas as pd
from pathlib import Path

# url = "https://www.rba.gov.au/statistics/tables/csv/g1-data.csv"
path = Path.cwd() / ".." / "data" / "raw" / "g1-data.csv"
df = pd.read_csv(path,encoding="latin1")
df
# Out:
#      G1 CONSUMER PRICE INFLATION                        Unnamed: 1  \
# 0                          Title              Consumer price index
# 1                    Description  Consumer price index; All groups
# 2                      Frequency                         Quarterly
# 3                           Type                          Original
# 4                          Units                Index, 2011/12=100
# ...                          ...                               ...
# 9993                         NaN                               NaN
# 9994                         NaN                               NaN
# 9995                         NaN                               NaN
# 9996                         NaN                               NaN
# 9997                         NaN                               NaN
#
#                                              Unnamed: 2  \
# 0                                  Year-ended inflation
# ...
