# %% [markdown]
# ## Driver to the modules
# After much fighting with ChatGPT to write the correct code...
# Note to self: ChatGPT is good for grunt work ...

# %%
#TODO: Modify nsw_units_pipeline.main - to write the LGA into the file name

# %%
# import pandas as pd 
import nsw_units_pipeline as pipeline
from lga_geometry import fetch_lga_geometry

TARGET_LGAS = [
    "Canada Bay",   # City of Canada Bay
    "Ryde",         # City of Ryde
    "Parramatta",   # City of Parramatta
]
for lga_name in TARGET_LGAS:
    print(f"\n=== Processing LGA: {lga_name} ===")
    lga_geom = fetch_lga_geometry("Ryde")
    pipeline.main(
        lga_geom_4326=lga_geom,
        lga_name=lga_name)
# Out:
# === Processing LGA: Canada Bay ===
# Starting pipeline for LGA: Canada Bay (canada_bay)
#
# Tile 1/4 .................................
# Tile 2/4 ................
# Tile 3/4 ...........
# Tile 4/4 .............
# Spatial pass complete: 72,166 unique records
# Current properties retained: 36,100
# CSV written → ../data/raw/nsw_units_current_canada_bay.csv
# Pipeline complete for Canada Bay
#
# === Processing LGA: Ryde ===
# Starting pipeline for LGA: Ryde (ryde)
#
# Tile 1/4 .................................
# Tile 2/4 ................
# Tile 3/4 ...........
# Tile 4/4 .............
# Spatial pass complete: 72,166 unique records
# Current properties retained: 36,100
# CSV written → ../data/raw/nsw_units_current_ryde.csv
# Pipeline complete for Ryde
#
# === Processing LGA: Parramatta ===
# Starting pipeline for LGA: Parramatta (parramatta)
#
# Tile 1/4 .................................
# Tile 2/4 ................
# Tile 3/4 ...........
# Tile 4/4 .............
# ...
