# %% [markdown]
# # Sourcing Data
#
# ## Portal Spacial NSW GOV AU
# https://portal.spatial.nsw.gov.au/portal/home/item.html?id=01de8834e88a45a1a673b120aa00c82e&sublayer=12&sortOrder=desc&sortField=defaultFSOrder#data
#
# | Field | Description |
# | --- | --- |
# | createddate | dd/mm/yyyy, h:nn AmPm |
# | propid | the unique property ID for a unit? eg. 376xxx |
# | principaladdresssiteoid | Is this this propid for the apartment block? eg. 3541872 |
# | PropertyType | not sure but the sample unit has Property |
# | valnetpropertystatus | _ignore_ not useful |
# | valnetpropertytype | _ignore_ not useful |
# | dissolveparcelcount | ? eg. 1 |
# | valnetlotcount | number of units in the block eg. 261 |
# | superlot | is this part of block - Y |
# | housenumber | is the address number eg. #/# |
# | address | the full street address #/# NAME STREET SUBURB |
# | startdate | The date/time the unit entered the system (occupancy cert?) |
# | enddate | Date the property was delisted - defaults to 1/1/3000 11:00 Am 32503680000000  |
# | msoid | tba may be a foreign key to a 'msid' eg. 3947307 |
# | urbanity | seems everything interesting is a U. TODO: What is this field |
# | changetype | tba eg. M |
# | principaladdresstype | 1 => Primary and 2 => Secondary - Primary means the unit block; secondary means the actual units  |
# | --- | --- |
#
# ## From Property Sales...
# https://valuation.property.nsw.gov.au/embed/propertySalesInformation
#
# Note: this doesn't seem to have the intital sale?
#
# ## Picking 2 properties sold on Walker St RHODES.
# TODO: Date of last sale is missing. Property ID is *wrong* - it might be the principal property id
# | Field | Value | Source | Description |
# | --- | --- | --- | --- |
# | **attributes** | **46 Walker Primary Address** | |
# | createdate | 1412972563000 | Spacial | Date record created |
# | gurasid | 78296348 | Spacial | ? |
# | principaladdresssiteoid | 3541872 | Spacial | ? |
# | propertytype | 1 | From Spacial
# | valnetpropertystatus | null | Spacial |
# | valnetpropertytype | null | Spacial |
# | dissolveparcelcount | 1 | Spacial |
# | valnetlotcount | 261 | Spacial |
# | valnetworkflowid | null | Spacial |
# | propid | 3764553 | Spacial |
# | superlot | Y |
# | housenumber | 46 |
# | address | 46 WALKER STREET RHODES |
# | startdate | 1412972594000 |
# | enddate | 32503680000000 |
# | lastupdate | 1412972651000 |
# | msoid | 3947307 |
# | centroidid | null |
# | shapeuuid | 99531aa4-f433-3fe8-9cb4-db2f2215a935 |
# | changetype | M |
# | processstate | null |
# | urbanity | U |
# | principaladdresstype | 1 |
# | addressstringoid | 6684080 |
# | Shape__Length | 0.0061614902279786199 |
# | Shape__Area | 2.7360584618294323e-07 |
# | OBJECTID | 5570718 |
# | centroid x | 151.0869811588025 |
# | centroid y | -33.827189721940186 |
#
# * Looking at : https://www.valuergeneral.nsw.gov.au/services/addr-inquiry.htm
# I can get the property number, Property Address and title reference.
# So 2004/46 Walker Street has property number 3765568
#
#
# ### Nature of Property
# Data below is derived from Valuer General ...
# | nature of property | primary purpose |
# | --- | --- |
# | R | RESIDENCE |
# | 3 | RETAIL |
# | V | VACANT LAND |
#
# ### Districts or LGAs
# | District Code | Local Government Area |
# | --- | --- |
# | 090 | Ryde |
# | 139 | Canada Bay |
# | 260 | City of Parramatta |
